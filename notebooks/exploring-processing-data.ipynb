# %%
#imports
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Import data

# %%
# set the path of raw data
raw_data_path = os.path.join(os.path.pardir, 'data', 'raw')
train_file_path = os.path.join(raw_data_path, 'train.csv')
test_file_path = os.path.join(raw_data_path, 'test.csv')

# %%
# read data with all default parameters
train_df = pd.read_csv(train_file_path, index_col='PassengerId')
test_df = pd.read_csv(test_file_path, index_col='PassengerId')

# %%
# get the type
type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Basic structure

# %%
# use .info to get brief information about the data frame
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
# Pclass      418 non-null int64
# Name        418 non-null object
# Sex         418 non-null object
# Age         332 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Ticket      418 non-null object
# Fare        417 non-null float64
# Cabin       91 non-null object
# Embarked    418 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
# adding default value so that structure of both data sets are same
test_df['Survived'] = -888

# %%
df = pd.concat((train_df, test_df), axis=0)
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
# Age         1046 non-null float64
# Cabin       295 non-null object
# Embarked    1307 non-null object
# Fare        1308 non-null float64
# Name        1309 non-null object
# Parch       1309 non-null int64
# Pclass      1309 non-null int64
# Sex         1309 non-null object
# SibSp       1309 non-null int64
# Survived    1309 non-null int64
# Ticket      1309 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 122.7+ KB

# %%
df.head()
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
#
#                 Sex  SibSp  Survived            Ticket
# PassengerId
# 1              male      1         0         A/5 21171
# 2            female      1         1          PC 17599
# 3            female      0         1  STON/O2. 3101282
# 4            female      1         1            113803
# 5              male      0         0            373450

# %%
df.head(7)
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 2            38.0   C85        C  71.2833
# 3            26.0   NaN        S   7.9250
# 4            35.0  C123        S  53.1000
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 7            54.0   E46        S  51.8625
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
# 6                                             Moran, Mr. James      0       3
# 7                                      McCarthy, Mr. Timothy J      0       1
#
#                 Sex  SibSp  Survived            Ticket
# PassengerId
# 1              male      1         0         A/5 21171
# 2            female      1         1          PC 17599
# 3            female      0         1  STON/O2. 3101282
# 4            female      1         1            113803
# 5              male      0         0            373450
# 6              male      0         0            330877
# 7              male      0         0             17463

# %%
df.tail()
# Out:
#               Age Cabin Embarked      Fare                          Name  \
# PassengerId
# 1305          NaN   NaN        S    8.0500            Spector, Mr. Woolf
# 1306         39.0  C105        C  108.9000  Oliva y Ocana, Dona. Fermina
# 1307         38.5   NaN        S    7.2500  Saether, Mr. Simon Sivertsen
# 1308          NaN   NaN        S    8.0500           Ware, Mr. Frederick
# 1309          NaN   NaN        C   22.3583      Peter, Master. Michael J
#
#              Parch  Pclass     Sex  SibSp  Survived              Ticket
# PassengerId
# 1305             0       3    male      0      -888           A.5. 3236
# 1306             0       1  female      0      -888            PC 17758
# 1307             0       3    male      0      -888  SOTON/O.Q. 3101262
# 1308             0       3    male      0      -888              359309
# 1309             1       3    male      1      -888                2668

# %%
df.Name
# Out:
# PassengerId
# 1                                 Braund, Mr. Owen Harris
# 2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                
vander Planke, Mrs. Julius (Emelia Maria Vande...
# 20                                Masselmani, Mrs. Fatima
# 21                                   Fynney, Mr. Joseph J
# 22                                  Beesley, Mr. Lawrence
# 23                            McGowan, Miss. Anna "Annie"
# 24                           Sloper, Mr. William Thompson
# 25                          Palsson, Miss. Torborg Danira
# 26      Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 27                                Emir, Mr. Farred Chehab
# 28                         Fortune, Mr. Charles Alexander
# 29                          O'Dwyer, Miss. Ellen "Nellie"
# 30                                    Todoroff, Mr. Lalio
#                               ...
# 1280                                 Canavan, Mr. Patrick
# 1281                          Palsson, Master. Paul Folke
# 1282                           Payne, Mr. Vivian Ponsonby
# 1283       Lines, Mrs. Ernest H (Elizabeth Lindsey James)
# 1284                        Abbott, Master. Eugene Joseph
# 1285                                 Gilbert, Mr. William
# 1286                             Kink-Heilmann, Mr. Anton
# 1287       Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 1288                                 Colbert, Mr. Patrick
# 1289    Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...
# 1290                       Larsson-Rondberg, Mr. Edvard A
# 1291                             Conlon, Mr. Thomas Henry
# 1292                              Bonnell, Miss. Caroline
# 1293                                      Gale, Mr. Harry
# 1294                       Gibson, Miss. Dorothy Winifred
# 1295                               Carrau, Mr. Jose Pedro
# 1296                         Frauenthal, Mr. Isaac Gerald
# 1297         Nourney, Mr. Alfred (Baron von Drachstedt")"
# 1298                            Ware, Mr. William Jeffery
# 1299                           Widener, Mr. George Dunton
# 1300                      Riordan, Miss. Johanna Hannah""
# 1301                            Peacock, Miss. Treasteall
# 1302                               Naughton, Miss. Hannah
# 1303      Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1304                       Henriksson, Miss. Jenny Lovisa
# 1305                                   Spector, Mr. Woolf
# 1306                         Oliva y Ocana, Dona. Fermina
# 1307                         Saether, Mr. Simon Sivertsen
# 1308                                  Ware, Mr. Frederick
# 1309                             Peter, Master. Michael J
# Name: Name, Length: 1309, dtype: object

# %%
df[[Name, Age]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-9296a2e7f469> in <module>()
# ----> 1 df[[Name, Age]]
#
# NameError: name 'Name' is not defined

# %%
df[['Name','Age']]

# %%
df.loc[5:10,]

# %%
df.loc[5:10,'Age':'Pclass']

# %%
print('foo')

# %%
df.loc[5:10,['Age', 'Embarked', 'Sex']]

# %%
print('foo')

# %%
df.iloc[5:10,3:8]

# %%
male_passangers = df.loc[df.Sex == 'male',:]
print('Number of Male passangers : {0}'.format(len(male_passangers)) )

# %%
male_passangers_first_class = df.loc[((df.Sex == 'male') & (df.Pclass == 1)),:]
print('Number of Male passangers in first class : {0}'.format(len(male_passangers_first_class)) )
print(male_passangers_first_class)

# %% [markdown]
# ## Summary statistics

# %%
# use describe to get statistics for all numerical values
df.describe()

# %%
# numerical features
# centrality measure
print('mean fare : {0}'.format(df.Fare.mean()))
print('median fare : {0}'.format(df.Fare.median()))

# %%
# dispersion measures
f = df.Fare
print('min fare : ${0}'.format(f.min()))
print('max fare : ${0}'.format(f.max()))
print('range : ${0}'.format(f.max() - f.min()))
print('25 percentile : ${0}'.format(f.quantile(.25)))
print('50 percentile : ${0}'.format(f.quantile(.5)))
print('75 percentile : ${0}'.format(f.quantile(.75)))
print('variance : ${0}'.format(f.var()))
print('std deviation : ${0}'.format(f.std()))

# %%
# whisker-box plot
# %matplotlib inline
df.Fare.plot(kind='box')

# %%
# use .describe(include='all') to get statistics for all columns including non-numeric
df.describe(include='all')

# %%
df.Sex.value_counts()

# %%
df.Sex.value_counts(normalize=True)

# %%
df[df.Survived != -888].Survived.value_counts()

# %%
df.Pclass.value_counts()

# %%
df.Pclass.value_counts().plot(kind='bar')

# %%
df.Pclass.value_counts().plot(kind='bar', rot=0, title='Class wise passanger count', color='c');

# %% [markdown]
# ## Distributions

# %%
# use hist to create histograms
df.Age.plot(kind='hist', title='Histogram for Age', color='c');

# %%
# use hist to create histograms
df.Age.plot(kind='hist', title='Histogram for Age', color='c', bins=20);

# %%
# use kde to create density plot
df.Age.plot(kind='kde', title='Density plot for Age', color='c');

# %%
# use hist to create histograms for Fare
df.Fare.plot(kind='hist', title='Histogram for Fare', color='c', bins=20);

# %%
print('skewness for Age : {0:2f}'.format(df.Age.skew()))
print('skewness for Fare : {0:2f}'.format(df.Fare.skew()))

# %%
# scatter plot for age and fare : bi-variate distribution
df.plot.scatter(x='Age', y='Fare', color='c', title='Scatter plot : Age vs Fare');

# %%
# scatter plot for age and fare : transparency
df.plot.scatter(x='Age', y='Fare', color='c', title='Scatter plot : Age vs Fare', alpha=0.1);

# %%
# scatter plot for Pclass and fare : transparency
df.plot.scatter(x='Pclass', y='Fare', color='c', title='Scatter plot : Pclass vs Fare');

# %% [markdown]
# ## Grouping an aggregations

# %%
# group by
# df.groupby('Sex').Age.median()
df.groupby('Sex').Age.mean()

# %%
# group by
df.groupby('Pclass').Fare.median()

# %%
df.groupby('Pclass').Age.median()

# %%
df.groupby('Pclass')['Age', 'Fare'].median()

# %%
df.groupby(['Pclass', 'Sex'])['Age', 'Fare'].median()

# %%
# aggregation
df.groupby('Pclass').agg({'Fare': 'median', 'Age': 'mean'})

# %%
# complicated aggregation
aggregation = {
    'Fare': {
        'mean_fare': 'mean',
        'median_fare' : 'median',
        'max_fare': max,
        'min_fare': np.min
    },
    'Age': {
        'median_age': 'median',
        'max_age': max,
        'min_age': min,
        'range_age': lambda(x): max(x)-min(x)
    }
}

# %%
df.groupby('Pclass').agg(aggregation)

# %%
df.groupby(['Pclass', 'Embarked']).Fare.median()

# %% [markdown]
# ## Crosstabs

# %%
#crosstabs
pd.crosstab(df.Sex, df.Pclass)

# %%
pd.crosstab(df.Sex, df.Pclass).plot(kind='bar');

# %% [markdown]
# ## Pivot tables

# %%
# pivot table using 4 params - index >
df.pivot_table(index='Sex', columns='Pclass', values='Age', aggfunc='mean')

# %%
df.groupby(['Sex', 'Pclass']).Age.mean().unstack()

# %% [markdown]
# ## Data munging

# %%
df.info()

# %% [markdown]
# # Data munging
# ##  Feature: Embarked

# %%
# extract values with embarked as null
df[df.Embarked.isnull()]

# %%
# how many people embarked from different points
df.Embarked.value_counts()

# %%
# as in example both of them survived, so find out which embarked point has highest survival rate
pd.crosstab(df[df.Survived != -888].Survived, df[df.Survived != -888].Embarked)

# %%
# option 2 : check one more criteria before deciding the missing value answer
df.groupby(['Pclass', 'Embarked']).Fare.median()

# %%
# replace missing values with 'C', inplace=True > change in the existing data
df.Embarked.fillna('C', inplace=True)

# %%
df[df.Embarked.isnull()]

# %%
df.info()

# %% [markdown]
# ## Feature : Fare

# %%
df[df.Fare.isnull()]

# %%
df.loc[(df.Pclass == 3) & (df.Embarked=='S'),'Fare'].median()

# %%
df.Fare.fillna(8.05, inplace=True)

# %%
df[df.Fare.isnull()]

# %%
df.info()

# %% [markdown]
# ## Feature: Age

# %%
df[df.Age.isnull()]

# %% [markdown]
# ### option 1 : replace all missing age with mean values

# %%
df.Age.plot(kind='hist', bins=20);

# %%
df.Age.mean()

# %%
df.Age.median()

# %% [markdown]
# ### option 2 : replace with median age of gender

# %%
df.groupby('Sex').Age.median()

# %%
df[df.Age.notnull()].boxplot('Age', 'Sex');

# %% [markdown]
# ### option 3 : replace with median age of Pclass

# %%
df[df.Age.notnull()].boxplot('Age', 'Pclass');

# %% [markdown]
# ### option 4: replace with median age of title

# %%
# get title
def getTitle(name):
    first_name_with_title = name.split(',')[1]
    title = first_name_with_title.split('.')[0]
    title = title.strip().lower()
    return title

# %%
df.Name.map(lambda x : getTitle(x))

# %%
df.Name.map(lambda x : getTitle(x)).unique()

# %%
def getTitle(name):
    title_group = {
      'mr': 'Mr',
      'mrs': 'Mrs',
      'mme': 'Mrs',
      'miss': 'Miss',
      'mlle': 'Miss',
      'master': 'Master',
      'don': 'Sir',
      'sir': 'Sir',
      'rev': 'Sir',
      'jonkheer': 'Sir',
      'dr': 'Officer',
      'major': 'Officer',
      'col': 'Officer',
      'capt': 'Officer',
      'ms': 'Mrs',
      'lady': 'Lady',
      'the countess': 'Lady',
      'dona': 'Lady'
    }
    first_name_with_title = name.split(',')[1]
    title = first_name_with_title.split('.')[0]
    title = title.strip().lower()
    return title_group[title]

# %%
df['Title'] = df.Name.map(lambda x : getTitle(x))

# %%
df.head()

# %%
df[df.Age.notnull()].boxplot('Age', 'Title');

# %%
# replacing missing age values
title_age_median = df.groupby('Title').Age.transform('median')
df.Age.fillna(title_age_median, inplace=True)

# %%
df.info()

# %% [markdown]
# ## Working with outliers

# %% [markdown]
# ### Age

# %%
#using histogram to understand distribution
df.Age.plot(kind="hist", bins=20);

# %%
df.loc[df.Age>70]
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 97           71.0    A5        C  34.6542
# 117          70.5   NaN        Q   7.7500
# 494          71.0   NaN        C  49.5042
# 631          80.0   A23        S  30.0000
# 852          74.0   NaN        S   7.7750
# 988          76.0   C46        S  78.8500
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 97                                   Goldschmidt, Mr. George B      0       1
# 117                                       Connors, Mr. Patrick      0       3
# 494                                    Artagaveytia, Mr. Ramon      0       1
# 631                       Barkworth, Mr. Algernon Henry Wilson      0       1
# 852                                        Svensson, Mr. Johan      0       3
# 988          Cavendish, Mrs. Tyrell William (Julia Florence...      0       1
#
#                 Sex  SibSp  Survived    Ticket
# PassengerId
# 97             male      0         0  PC 17754
# 117            male      0         0    370369
# 494            male      0         0  PC 17609
# 631            male      0         1     27042
# 852            male      0         0    347060
# 988          female      1      -888     19877

# %% [markdown]
# ### Fare

# %%
# histogram for fare
df.Fare.plot(kind='hist', bins=20);

# %%
df.loc[df.Fare > 300]
# Out:
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 259          35.0          NaN        C  512.3292
# 680          36.0  B51 B53 B55        C  512.3292
# 738          35.0         B101        C  512.3292
# 1235         58.0  B51 B53 B55        C  512.3292
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 259                                           Ward, Miss. Anna      0       1
# 680                         Cardeza, Mr. Thomas Drake Martinez      1       1
# 738                                     Lesurer, Mr. Gustave J      0       1
# 1235         Cardeza, Mrs. James Warburton Martinez (Charlo...      1       1
#
#                 Sex  SibSp  Survived    Ticket
# PassengerId
# 259          female      0         1  PC 17755
# 680            male      0         1  PC 17755
# 738            male      0         1  PC 17755
# 1235         female      0      -888  PC 17755

# %%
df.Fare.plot(kind='box');

# %%
# trying transformations to reduce skewness 
LogFare = np.log(df.Fare + 1) # adding 1, as some fares are 0 and log(0) is not defined

# %%
# histogram for logfare
LogFare.hist(bins=10);

# %%
#binning
pd.qcut(df.Fare, 4)
# Out:
# PassengerId
# 1         (-0.001, 7.896]
# 2       (31.275, 512.329]
# 3         (7.896, 14.454]
# 4       (31.275, 512.329]
# 5         (7.896, 14.454]
# 6         (7.896, 14.454]
# 7       (31.275, 512.329]
# 8        (14.454, 31.275]
# 9         (7.896, 14.454]
# 10       (14.454, 31.275]
# 11       (14.454, 31.275]
# 12       (14.454, 31.275]
# 13        (7.896, 14.454]
# 14       (14.454, 31.275]
# 15        (-0.001, 7.896]
# 16       (14.454, 31.275]
# 17       (14.454, 31.275]
# 18        (7.896, 14.454]
# 19       (14.454, 31.275]
# 20        (-0.001, 7.896]
# 21       (14.454, 31.275]
# 22        (7.896, 14.454]
# 23        (7.896, 14.454]
# 24      (31.275, 512.329]
# 25       (14.454, 31.275]
# 26      (31.275, 512.329]
# 27        (-0.001, 7.896]
# 28      (31.275, 512.329]
# 29        (-0.001, 7.896]
# 30        (-0.001, 7.896]
#               ...
# 1280      (-0.001, 7.896]
# 1281     (14.454, 31.275]
# 1282    (31.275, 512.329]
# 1283    (31.275, 512.329]
# 1284     (14.454, 31.275]
# 1285      (7.896, 14.454]
# 1286     (14.454, 31.275]
# 1287    (31.275, 512.329]
# 1288      (-0.001, 7.896]
# 1289    (31.275, 512.329]
# 1290      (-0.001, 7.896]
# 1291      (-0.001, 7.896]
# 1292    (31.275, 512.329]
# 1293     (14.454, 31.275]
# 1294    (31.275, 512.329]
# 1295    (31.275, 512.329]
# 1296     (14.454, 31.275]
# 1297      (7.896, 14.454]
# 1298      (7.896, 14.454]
# 1299    (31.275, 512.329]
# 1300      (-0.001, 7.896]
# 1301      (7.896, 14.454]
# 1302      (-0.001, 7.896]
# 1303    (31.275, 512.329]
# 1304      (-0.001, 7.896]
# 1305      (7.896, 14.454]
# 1306    (31.275, 512.329]
# 1307      (-0.001, 7.896]
# 1308      (7.896, 14.454]
# 1309     (14.454, 31.275]
# Name: Fare, Length: 1309, dtype: category
# Categories (4, interval[float64]): [(-0.001, 7.896] < (7.896, 14.454] < (14.454, 31.275] < (31.275, 512.329]]

# %%
pd.qcut(df.Fare, 4, labels=['very_low', 'low', 'high', 'very_high'])
# Out:
# PassengerId
# 1        very_low
# 2       very_high
# 3             low
# 4       very_high
# 5             low
# 6             low
# 7       very_high
# 8            high
# 9             low
# 10           high
# 11           high
# 12           high
# 13            low
# 14           high
# 15       very_low
# 16           high
# 17           high
# 18            low
# 19           high
# 20       very_low
# 21           high
# 22            low
# 23            low
# 24      very_high
# 25           high
# 26      very_high
# 27       very_low
# 28      very_high
# 29       very_low
# 30       very_low
#           ...
# 1280     very_low
# 1281         high
# 1282    very_high
# 1283    very_high
# 1284         high
# 1285          low
# 1286         high
# 1287    very_high
# 1288     very_low
# 1289    very_high
# 1290     very_low
# 1291     very_low
# 1292    very_high
# 1293         high
# 1294    very_high
# 1295    very_high
# 1296         high
# 1297          low
# 1298          low
# 1299    very_high
# 1300     very_low
# 1301          low
# 1302     very_low
# 1303    very_high
# 1304     very_low
# 1305          low
# 1306    very_high
# 1307     very_low
# 1308          low
# 1309         high
# Name: Fare, Length: 1309, dtype: category
# Categories (4, object): [very_low < low < high < very_high]

# %%
pd.qcut(df.Fare, 4, labels=['very_low', 'low', 'high', 'very_high']).value_counts().plot(kind='bar', rot=0);

# %%
df['Fare_bin'] = pd.qcut(df.Fare, 4, labels=['very_low', 'low', 'high', 'very_high'])

# %%
df.loc[df.Fare < 50]
# Out:
#               Age Cabin Embarked     Fare  \
# PassengerId
# 1            22.0   NaN        S   7.2500
# 3            26.0   NaN        S   7.9250
# 5            35.0   NaN        S   8.0500
# 6             NaN   NaN        Q   8.4583
# 8             2.0   NaN        S  21.0750
# 9            27.0   NaN        S  11.1333
# 10           14.0   NaN        C  30.0708
# 11            4.0    G6        S  16.7000
# 12           58.0  C103        S  26.5500
# 13           20.0   NaN        S   8.0500
# 14           39.0   NaN        S  31.2750
# 15           14.0   NaN        S   7.8542
# 16           55.0   NaN        S  16.0000
# 17            2.0   NaN        Q  29.1250
# 18            NaN   NaN        S  13.0000
# 19           31.0   NaN        S  18.0000
# 20            NaN   NaN        C   7.2250
# 21           35.0   NaN        S  26.0000
# 22           34.0   D56        S  13.0000
# 23           15.0   NaN        Q   8.0292
# 24           28.0    A6        S  35.5000
# 25            8.0   NaN        S  21.0750
# 26           38.0   NaN        S  31.3875
# 27            NaN   NaN        C   7.2250
# 29            NaN   NaN        Q   7.8792
# 30            NaN   NaN        S   7.8958
# 31           40.0   NaN        C  27.7208
# 33            NaN   NaN        Q   7.7500
# 34           66.0   NaN        S  10.5000
# 37            NaN   NaN        C   7.2292
# 1295           male      0      -888              113059  very_high
# 1296           male      1      -888               17765       high
# 1297           male      0      -888       SC/PARIS 2166        low
# 1298           male      1      -888               28666        low
# 1300         female      0      -888              334915   very_low
# 1301         female      1      -888  SOTON/O.Q. 3101315        low
# 1302         female      0      -888              365237   very_low
# 1304         female      0      -888              347086   very_low
# 1305           male      0      -888           A.5. 3236        low
# 1307           male      0      -888  SOTON/O.Q. 3101262   very_low
# 1308           male      0      -888              359309        low
# 1309           male      1      -888                2668       high
#
# [1066 rows x 12 columns]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Feature :  Age State (Adult or Child)

# %%
# age state based on age
df['AgeState'] = np.where(df['Age'] >= 18, 'Adult', 'Child')

# %%
df['AgeState'].value_counts()
# Out:
# Adult    892
# Child    417
# Name: AgeState, dtype: int64

# %%
pd.crosstab(df[df.Survived != -888].Survived, df[df.Survived != -888].AgeState)
# Out:
# AgeState  Adult  Child
# Survived
# 0           372    177
# 1           229    113

# %% [markdown]
# ### Feature: Family Size

# %%
df['FamilySize'] = df.Parch + df.SibSp + 1

# %%
df['FamilySize'].plot(kind='hist');

# %%
df.loc[df.FamilySize == df.FamilySize.max()]
# Out:
#               Age Cabin Embarked   Fare                               Name  \
# PassengerId
# 160           NaN   NaN        S  69.55         Sage, Master. Thomas Henry
# 181           NaN   NaN        S  69.55       Sage, Miss. Constance Gladys
# 202           NaN   NaN        S  69.55                Sage, Mr. Frederick
# 325           NaN   NaN        S  69.55           Sage, Mr. George John Jr
# 793           NaN   NaN        S  69.55            Sage, Miss. Stella Anna
# 847           NaN   NaN        S  69.55           Sage, Mr. Douglas Bullen
# 864           NaN   NaN        S  69.55  Sage, Miss. Dorothy Edith "Dolly"
# 1080          NaN   NaN        S  69.55                    Sage, Miss. Ada
# 1234          NaN   NaN        S  69.55              Sage, Mr. John George
# 1252         14.5   NaN        S  69.55        Sage, Master. William Henry
# 1257          NaN   NaN        S  69.55     Sage, Mrs. John (Annie Bullen)
#
#              Parch  Pclass     Sex  SibSp  Survived    Ticket AgeState  \
# PassengerId
# 160              2       3    male      8         0  CA. 2343    Child
# 181              2       3  female      8         0  CA. 2343    Child
# 202              2       3    male      8         0  CA. 2343    Child
# 325              2       3    male      8         0  CA. 2343    Child
# 793              2       3  female      8         0  CA. 2343    Child
# 847              2       3    male      8         0  CA. 2343    Child
# 864              2       3  female      8         0  CA. 2343    Child
# 1080             2       3  female      8      -888  CA. 2343    Child
# 1234             9       3    male      1      -888  CA. 2343    Child
# 1252             2       3    male      8      -888  CA. 2343    Child
# 1257             9       3  female      1      -888  CA. 2343    Child
#
#              FamilySize
# PassengerId
# 160                  11
# 181                  11
# 202                  11
# 325                  11
# 793                  11
# 847                  11
# 864                  11
# 1080                 11
# 1234                 11
# 1252                 11
# 1257                 11

# %%
pd.crosstab(df[df.Survived != -888].Survived, df[df.Survived != -888].FamilySize)
# Out:
# FamilySize   1   2   3   4   5   6   7   8   11
# Survived
# 0           374  72  43   8  12  19   8   6   7
# 1           163  89  59  21   3   3   4   0   0
